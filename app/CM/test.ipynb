# %%
from CM_DB_Handler import CMDatabaseHandler

# Initialize database handler with credentials from passcode.json
db_handler = CMDatabaseHandler(json_file="passcode.json", db_key="CM")

# Connect to database
if db_handler.connect():
    print("Database connection established successfully.")
else:
    print("Failed to connect to database.")
chats = db_handler.execute_query_from_file("../SQL/CM_Chat_Search.sql", params={
    "ConversationId": None,
    "AgentFullName": None,
    "AgentEmail": "Nada.Abdullah@Andalusiagroup.net",
    "FilterDate": "2026-06-05"
})
print(f"✓ Query executed successfully")
# Out:
# ✓ Credentials loaded from passcode.json for key 'CM'
# ✓ Connected to ksa-booking-01.master
# Database connection established successfully.
# Executing query from: ../SQL/CM_Chat_Search.sql
# Parameters substituted: ['ConversationId', 'AgentFullName', 'AgentEmail', 'FilterDate']
# /home/ai/Workspace/Rafik/QA_System-main/app/CM/CM_DB_Handler.py:139: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, self.connection)
# ✓ Query executed successfully. Retrieved 928 rows.
# ✓ Query executed successfully

# %%
# Display retrieved chats
if chats is not None:
    print(f"\nRetrieved {len(chats)} chat conversations:")
    print(chats['UniqueId'].unique())
else:
    print("No chats retrieved.")
    
# Close connection when done
db_handler.close()
# Out:
# Retrieved 928 chat conversations:
# <StringArray>
# ['7EE29626-DC60-F111-8FCB-00224888EC9A',
#  '84058371-DA60-F111-8FCB-00224888EC9A',
#  'D8A9B517-DA60-F111-8FCB-00224888EC9A',
#  'CBAC029A-D960-F111-8FCB-00224888EC9A',
#  '2FE61455-D760-F111-8FCB-00224888EC9A',
#  'AF6D8FAD-D660-F111-8FCB-00224888EC9A',
#  'E573EBCF-D560-F111-8FCB-00224888EC9A',
#  'CD4C19A0-D560-F111-8FCB-00224888EC9A',
#  '8C3384EC-D460-F111-8FCB-00224888EC9A',
#  'E085D07A-D460-F111-8FCB-00224888EC9A',
#  '8DDD367F-D360-F111-8FCB-00224888EC9A',
#  'D33E73E9-D260-F111-8FCB-00224888EC9A',
#  'E1913E58-D160-F111-8FCB-00224888EC9A',
#  '8CDA1733-D060-F111-8FCB-00224888EC9A',
#  'FB1C869D-CF60-F111-8FCB-00224888EC9A',
#  '3AC1A32B-CF60-F111-8FCB-00224888EC9A',
#  'FAA7D5FB-CE60-F111-8FCB-00224888EC9A',
#  '3A7DF8D1-CE60-F111-8FCB-00224888EC9A',
#  'F7CBF2D7-CE60-F111-8FCB-00224888EC9A',
#  'EB88B290-C660-F111-8FCB-00224888EC9A',
#  '2466F01E-C660-F111-8FCB-00224888EC9A',
#  'B407EDAB-C460-F111-8FCB-00224888EC9A',
#  'F2C90876-C460-F111-8FCB-00224888EC9A',
#  'ECEC55C1-C260-F111-8FCB-00224888EC9A',
#  '824DBDBE-C060-F111-8FCB-00224888EC9A',
#  '656D253B-C060-F111-8FCB-00224888EC9A',
#  '6AFEB2A5-BF60-F111-8FCB-00224888EC9A',
#  '4B6131E5-BD60-F111-8FCB-00224888EC9A',
#  'EB29AA06-BC60-F111-8FCB-00224888EC9A',
#  '59BDF00E-B960-F111-8FCB-00224888EC9A',
#  'F6865F97-B860-F111-8FCB-00224888EC9A',
#  'A2DB9A3D-B860-F111-8FCB-00224888EC9A',
#  '138CF8C5-B760-F111-8FCB-00224888EC9A',
#  '8D9D9F9C-B360-F111-8FCB-00224888EC9A',
#  'C72DAA78-B360-F111-8FCB-00224888EC9A',
#  '3915BBD2-B360-F111-8FCB-00224888EC9A',
#  '522C5565-B260-F111-8FCB-00224888EC9A',
#  '262C5565-B260-F111-8FCB-00224888EC9A',
#  'B988EB0C-B360-F111-8FCB-00224888EC9A',
#  '3B42218E-B160-F111-8FCB-00224888EC9A',
#  '126F2A4C-B160-F111-8FCB-00224888EC9A',
#  '5DDE4E28-B160-F111-8FCB-00224888EC9A',
#  '2C9D29A9-AF60-F111-8FCB-00224888EC9A',
#  '52A948FA-AD60-F111-8FCB-00224888EC9A',
#  '3A762F57-AC60-F111-8FCB-00224888EC9A',
#  '1A975E1F-AB60-F111-8FCB-00224888EC9A',
#  '3FE05819-AB60-F111-8FCB-00224888EC9A',
#  '75389A79-A660-F111-8FCB-00224888EC9A',
#  'FF46A073-A660-F111-8FCB-00224888EC9A',
#  '07F5384F-A660-F111-8FCB-00224888EC9A',
#  '5EB23449-A460-F111-8FCB-00224888EC9A',
#  'C9062A99-A260-F111-8FCB-00224888EC9A',
#  '3636E651-9F60-F111-8FCB-00224888EC9A',
#  '0FC928B2-9E60-F111-8FCB-00224888EC9A',
#  'BFF61E5E-9D60-F111-8FCB-00224888EC9A',
#  'A0F8D57E-8A60-F111-8FCB-00224888EC9A']
# Length: 56, dtype: str
# ✓ Database connection closed

# %%
chats[['Content','AgentFullName','UniqueId','SenderIdName','SenderType','RelationName']].loc[chats['UniqueId'] == 'D8A9B517-DA60-F111-8FCB-00224888EC9A']
# Out:
#                                               Content AgentFullName  \
# 31  السـلام عليكـم مـع حضـرتـك ندي من مجموعة أندلس...    Nada Essam
# 32                                       عليكم السلام    Nada Essam
# 33                                              أجوان    Nada Essam
# 34                          عندي موعد غدا واود تأكيده    Nada Essam
# 35   اهلا وسهلا أ/ أجوان\r\nأتمنى تكون بصحة وعافية...    Nada Essam
# 36                                             الوووو    Nada Essam
# 37                         موعدك غدا موكد مع د/ داليا    Nada Essam
# 38                                               تمام    Nada Essam
# 39                                      على الساعه كم    Nada Essam
# 40                                                 7م    Nada Essam
# 41                                               تمام    Nada Essam
# 42                      اقدر اساعدك في اي شئ اخر؟\r\n    Nada Essam
# 43                                       <div>d</div>    Nada Essam
# 44   شكرًا لتواصلكم مع مجموعة أندلسية صحة، نتمنى ل...    Nada Essam
#
#                                 UniqueId       SenderIdName SenderType  \
# 31  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
# 32  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 33  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 34  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 35  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
# 36  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 37  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
# 38  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 39  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 40  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
# 41  D8A9B517-DA60-F111-8FCB-00224888EC9A  سبحان الله وبحمده   Relation
# 42  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
# 43  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
# 44  D8A9B517-DA60-F111-8FCB-00224888EC9A               Nada       User
#
#          RelationName
# 31  سبحان الله وبحمده
# 32  سبحان الله وبحمده
# 33  سبحان الله وبحمده
# 34  سبحان الله وبحمده
# 35  سبحان الله وبحمده
# 36  سبحان الله وبحمده
# 37  سبحان الله وبحمده
# 38  سبحان الله وبحمده
# 39  سبحان الله وبحمده
# 40  سبحان الله وبحمده
# 41  سبحان الله وبحمده
# 42  سبحان الله وبحمده
# 43  سبحان الله وبحمده
# 44  سبحان الله وبحمده

# %%
from pathlib import Path
import sys

# Ensure project root (parent of "app") is on sys.path so "app" can be imported
project_root = Path.cwd().parent.parent.resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from app.models.input import BatchCallTranscripts, CallTranscript
from pydantic import ValidationError
import pandas as pd
# Out:
# /home/ai/Workspace/Rafik/QA_System-main/app/models/input.py:260: SyntaxWarning: invalid escape sequence '\d'
#   """ from typing import Optional

# %%
def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
    """
    Convert a message-level DataFrame (one row per message) into a
    BatchCallTranscripts.  Call this directly in tests or notebooks.
    """
    calls: list[CallTranscript] = []
    errors: list[dict] = []

    for uid, group in df.groupby("UniqueId", sort=False):
        # Convert each row to a plain dict; Timestamps stay as-is for _to_datetime()
        rows = group.to_dict(orient="records")
        try:
            calls.append(CallTranscript.from_cm_rows(rows))
        except (ValidationError, ValueError) as exc:
            # Log and skip bad conversations rather than aborting the whole batch
            errors.append({"UniqueId": uid, "error": str(exc)})

    if errors:
        import logging
        for e in errors:
            logging.warning("Skipped conversation %s: %s", e["UniqueId"], e["error"])

    return BatchCallTranscripts(calls=calls)

# %%
import warnings



# ── Usage ────────────────────────────────────────────────────────────────────

# Option A: from a live DB connection
#batch = load_batch_from_db("mssql+pyodbc://...")
# Ensure df_to_batch won't create a BatchCallTranscripts with >50 calls (pydantic limit).
# Wrap the existing df_to_batch to truncate to the first 50 conversations if needed.
_original_df_to_batch = df_to_batch

def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
    uids = list(df['UniqueId'].unique())
    if len(uids) <= 50:
        return _original_df_to_batch(df)
    # keep the first 50 unique conversation ids
    first_uids = set(uids[:50])
    df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
    warnings.warn(
        f"Input contains {len(uids)} conversations; truncating to first 50 unique conversations to satisfy BatchCallTranscripts limit."
    )
    return _original_df_to_batch(df_chunk)
# Option B: from a DataFrame you already have (notebook / test)
batch = _original_df_to_batch(chats) if len(chats['UniqueId'].unique()) <= 50 else df_to_batch(chats)

# Serialize to JSON for the pipeline ingestion node
payload: str = batch.model_dump_json()
out_path = project_root / "data" / "chats.json"
out_path.parent.mkdir(parents=True, exist_ok=True)
out_path.write_text(payload, encoding="utf-8")
print(f"Wrote chats JSON to {out_path}")

# Or as a dict if you're passing it directly in Python
payload_dict: dict = batch.model_dump()
# Out:
# /tmp/ipykernel_10837/1133316206.py:20: UserWarning: Input contains 56 conversations; truncating to first 50 unique conversations to satisfy BatchCallTranscripts limit.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[15], line 25
#      21         f"Input contains {len(uids)} conversations; truncating to first 50 unique conversations to satisfy BatchCallTranscripts limit."
#      22     )
#      23     return _original_df_to_batch(df_chunk)
#      24 # Option B: from a DataFrame you already have (notebook / test)
# ---> 25 batch = df_to_batch(chats)
#      26
#      27 # Serialize to JSON for the pipeline ingestion node
#      28 payload: str = batch.model_dump_json()
#
# Cell In[15], line 23, in df_to_batch(df)
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#      20     warnings.warn(
#      21         f"Input contains {len(uids)} conversations; truncating to first 50 unique conversations to satisfy BatchCallTranscripts limit."
#      22     )
# ---> 23     return _original_df_to_batch(df_chunk)
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
# ...
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 16, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
#      14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
# ---> 16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#      18     first_uids = set(uids[:50])
#      19     df_chunk = df.loc[df['UniqueId'].isin(first_uids)]
#
# Cell In[15], line 14, in df_to_batch(df)
#      13 def df_to_batch(df: pd.DataFrame) -> BatchCallTranscripts:
# ---> 14     uids = list(df['UniqueId'].unique())
#      15     if len(uids) <= 50:
#      16         return _original_df_to_batch(df)
#      17     # keep the first 50 unique conversation ids
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/series.py:2228, in Series.unique(self)
#    2163 def unique(self) -> ArrayLike:
#    2164     """
#    2165     Return unique values of Series object.
#    2166
#    (...)   2226     Categories (3, str): ['a' < 'b' < 'c']
#    2227     """
# -> 2228     return super().unique()
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/base.py:1157, in IndexOpsMixin.unique(self)
#    1154 values = self._values
#    1155 if not isinstance(values, np.ndarray):
#    1156     # i.e. ExtensionArray
# -> 1157     result = values.unique()
#    1158 else:
#    1159     result = algorithms.unique1d(values)  # type: ignore[assignment]
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/arrays/_mixins.py:232, in NDArrayBackedExtensionArray.unique(self)
#     231 def unique(self) -> Self:
# --> 232     new_data = unique(self._ndarray)
#     233     return self._from_backing_data(new_data)
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/algorithms.py:433, in unique(values)
#     327 @set_module("pandas")
#     328 def unique(values):
#     329     """
#     330     Return unique values based on a hash table.
#     331
#    (...)    431     Length: 3, dtype: complex128
#     432     """
# --> 433     return unique_with_mask(values)
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/algorithms.py:472, in unique_with_mask(values, mask)
#     469     return values.unique()
#     471 original = values
# --> 472 hashtable, values = _get_hashtable_algo(values)
#     474 table = hashtable(len(values))
#     475 if mask is None:
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/algorithms.py:287, in _get_hashtable_algo(values)
#     274 def _get_hashtable_algo(
#     275     values: np.ndarray,
#     276 ) -> tuple[type[htable.HashTable], np.ndarray]:
#     277     """
#     278     Parameters
#     279     ----------
#    (...)    285     values : ndarray
#     286     """
# --> 287     values = _ensure_data(values)
#     289     ndtype = _check_object_for_strings(values)
#     290     hashtable = _hashtables[ndtype]
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/algorithms.py:140, in _ensure_data(values)
#     136 if not isinstance(values, ABCMultiIndex):
#     137     # extract_array would raise
#     138     values = extract_array(values, extract_numpy=True)
# --> 140 if is_object_dtype(values.dtype):
#     141     return ensure_object(np.asarray(values))
#     143 elif isinstance(values.dtype, BaseMaskedDtype):
#     144     # i.e. BooleanArray, FloatingArray, IntegerArray
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/dtypes/common.py:185, in is_object_dtype(arr_or_dtype)
#     142 @set_module("pandas.api.types")
#     143 def is_object_dtype(arr_or_dtype) -> bool:
#     144     """
#     145     Check whether an array-like or dtype is of the object dtype.
#     146
#    (...)    183     False
#     184     """
# --> 185     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#
# File ~/Workspace/Rafik/QA_System-main/venv/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1678, in _is_dtype_type(arr_or_dtype, condition)
#    1676 # fastpath
#    1677 if isinstance(arr_or_dtype, np.dtype):
# -> 1678     return condition(arr_or_dtype.type)
#    1679 elif isinstance(arr_or_dtype, type):
#    1680     if issubclass(arr_or_dtype, ExtensionDtype):
#
# RecursionError: maximum recursion depth exceeded

# %%
# Serialize to JSON for the pipeline ingestion node
payload: str = batch.model_dump_json()
out_path = project_root / "data" / "chats.json"
out_path.parent.mkdir(parents=True, exist_ok=True)
out_path.write_text(payload, encoding="utf-8")
print(f"Wrote chats JSON to {out_path}")

# Or as a dict if you're passing it directly in Python
payload_dict: dict = batch.model_dump()
